# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("bank-additional.csv", delimiter=";")
df.rename(columns= {'y' : 'Deposit'}, inplace=True)
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
df.info() # to display the top 5 values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
df.tail() # used to display the last 5 values
# Out:
#       age         job  marital    education default housing loan    contact  \
# 4114   30      admin.  married     basic.6y      no     yes  yes   cellular
# 4115   39      admin.  married  high.school      no     yes   no  telephone
# 4116   27     student   single  high.school      no      no   no   cellular
# 4117   58      admin.  married  high.school      no      no   no   cellular
# 4118   34  management   single  high.school      no     yes   no   cellular
#
#      month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 4114   jul         thu  ...         1    999         0  nonexistent
# 4115   jul         fri  ...         1    999         0  nonexistent
# 4116   may         mon  ...         2    999         1      failure
# 4117   aug         fri  ...         1    999         0  nonexistent
# 4118   nov         wed  ...         1    999         0  nonexistent
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# ...

# %%
df.shape
# Out:
# (4119, 21)

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'Deposit'],
#       dtype='object')

# %%
df.dtypes.value_counts()  # tells us the total of all the data types present
# Out:
# object     11
# int64       5
# float64     5
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()  # an alternate is .isnull() but this aligns with fillna and dropna commands
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# Deposit           0
# dtype: int64

# %%
cat_cols = df.select_dtypes(include = 'object').columns  # shows the categorical values
print(cat_cols)

num_cols = df.select_dtypes(exclude = 'object').columns
print(num_cols)
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'Deposit'],
#       dtype='object')
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
df.describe(include='object')
# Out:
#            job  marital          education default housing  loan   contact  \
# count     4119     4119               4119    4119    4119  4119      4119
# unique      12        4                  8       3       3     3         2
# top     admin.  married  university.degree      no     yes    no  cellular
# freq      1012     2509               1264    3315    2175  3349      2652
#
#        month day_of_week     poutcome Deposit
# count   4119        4119         4119    4119
# unique    10           5            3       2
# top      may         thu  nonexistent      no
# freq    1378         860         3523    3668

# %%
df.hist(figsize = (10,10), color = ["blue"])
plt.show()

# %%
# Calculate the number of rows and columns for subplots
num_plots = len(cat_cols)
num_rows = (num_plots + 1) // 2  # Add 1 and divide by 2 to round up for odd numbers
num_cols = 2

# Create a new figure
plt.figure(figsize=(15, 20))  # Adjust the figure size as needed

# Loop through each feature and create a countplot
for i, feature in enumerate(cat_cols, 1):
    plt.subplot(num_rows, num_cols, i)
    sns.countplot(x=feature, data=df, palette='Wistia')
    plt.title(f'Bar Plot of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.xticks(rotation=45)

# Adjust layout to prevent overlap of subplots
plt.tight_layout()
plt.show()

# %%
numeric_df = df.drop(columns=cat_cols)
corr = numeric_df.corr() # Compute the correlation matrix
print(corr)

corr = corr[abs(corr) >= 0.90]

sns.heatmap(corr,annot=True,cmap='Set3',linewidths=0.2)
plt.show()
# Out:
#                 age  duration  campaign     pdays  previous  emp.var.rate  \
# age             NaN       NaN       NaN       NaN       NaN           NaN
# duration        NaN       NaN       NaN       NaN       NaN           NaN
# campaign        NaN       NaN       NaN       NaN       NaN           NaN
# pdays           NaN       NaN       NaN  1.000000 -0.587941      0.270684
# previous        NaN       NaN       NaN -0.587941  1.000000     -0.415238
# emp.var.rate    NaN       NaN       NaN  0.270684 -0.415238      1.000000
# cons.price.idx  NaN       NaN       NaN  0.058472 -0.164922      0.755155
# cons.conf.idx   NaN       NaN       NaN -0.092090 -0.051420      0.195022
# euribor3m       NaN       NaN       NaN  0.301478 -0.458851      0.970308
# nr.employed     NaN       NaN       NaN  0.381983 -0.514853      0.897173
#
#                 cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# age                        NaN            NaN        NaN          NaN
# ...

# %%
high_corr_cols = ['emp.var.rate','euribor3m','nr.employed']
df1 = df.copy()
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'Deposit'],
#       dtype='object')

# %%
df1.drop(high_corr_cols,inplace=True,axis=1)  # axis=1 indicates columns
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'cons.price.idx', 'cons.conf.idx', 'Deposit'],
#       dtype='object')

# %%
df1.shape
# Out:
# (4119, 18)

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
df_encoded = df1.apply(lb.fit_transform)
df_encoded
# Out:
#       age  job  marital  education  default  housing  loan  contact  month  \
# 0       0    1        1          2        0        2     0        0      6
# 1       0    7        2          3        0        0     0        1      6
# 2       0    7        1          3        0        2     0        1      4
# 3       0    7        1          2        0        1     1        1      4
# 4       0    0        1          6        0        2     0        0      7
# ...   ...  ...      ...        ...      ...      ...   ...      ...    ...
# 4114    0    0        1          1        0        2     2        0      3
# 4115    0    0        1          3        0        2     0        1      3
# 4116    0    8        2          3        0        0     0        0      6
# 4117    0    0        1          3        0        0     0        0      1
# 4118    0    4        2          3        0        2     0        0      7
#
#       day_of_week  duration  campaign  pdays  previous  poutcome  \
# ...

# %%
df_encoded["Deposit"].value_counts()
# Out:
# Deposit
# 0    3668
# 1     451
# Name: count, dtype: int64

# %%
x = df_encoded.drop('Deposit',axis=1)  # independent variable
y = df_encoded['Deposit']              # dependent variable
print(x.shape)
print(y.shape)
print(type(x))
print(type(y))
# Out:
# (4119, 17)
# (4119,)
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3089, 17)
# (1030, 17)
# (3089,)
# (1030,)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

def eval_model(y_test,y_pred):
    acc = accuracy_score(y_test,y_pred)
    print('Accuracy_Score',acc)
    cm = confusion_matrix(y_test,y_pred)
    print('Confusion Matrix\n',cm)
    print('Classification Report\n',classification_report(y_test,y_pred))

def mscore(model):
    train_score = model.score(x_train,y_train)
    test_score = model.score(x_test,y_test)
    print('Training Score',train_score)
    print('Testing Score',test_score)

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_split=10)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=10)

# %%
mscore(dt)
# Out:
# Training Score 0.9080608611201036
# Testing Score 0.9067961165048544

# %%
ypred_dt = dt.predict(x_test)
print(ypred_dt)
# Out:
# [0 0 1 ... 0 0 0]

# %%
eval_model(y_test,ypred_dt)
# Out:
# Accuracy_Score 0.9067961165048544
# Confusion Matrix
#  [[915  15]
#  [ 81  19]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       930
#            1       0.56      0.19      0.28       100
#
#     accuracy                           0.91      1030
#    macro avg       0.74      0.59      0.62      1030
# weighted avg       0.88      0.91      0.89      1030

# %%
from sklearn.tree import plot_tree
cn = ['no','yes']
fn = x_train.columns
print(fn)
print(cn)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'cons.price.idx', 'cons.conf.idx'],
#       dtype='object')
# ['no', 'yes']

# %%
plt.figure(figsize=(30,10))
plot_tree(dt,class_names=cn,filled=True)
plt.show()

# %%
dt1 = DecisionTreeClassifier(criterion='entropy',max_depth=4,min_samples_split=15)
dt1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_split=15)

# %%
mscore(dt1)
# Out:
# Training Score 0.9051472968598252
# Testing Score 0.9067961165048544

# %%
ypred_dt1 = dt1.predict(x_test)
eval_model(y_test,ypred_dt1)
# Out:
# Accuracy_Score 0.9067961165048544
# Confusion Matrix
#  [[916  14]
#  [ 82  18]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       930
#            1       0.56      0.18      0.27       100
#
#     accuracy                           0.91      1030
#    macro avg       0.74      0.58      0.61      1030
# weighted avg       0.88      0.91      0.88      1030

# %%
plt.figure(figsize=(40,20))
plot_tree(dt1,class_names=cn,filled=True)
plt.show()
